# %% [markdown]
# learning rate = 0.00001

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 22s 450us/step - loss: 2.2206 - acc: 0.1680 - val_loss: 2.0613 - val_acc: 0.2596
# Epoch 2/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 2.0193 - acc: 0.2572 - val_loss: 1.9285 - val_acc: 0.3284
# Epoch 3/30
# 50000/50000 [==============================] - 21s 413us/step - loss: 1.8950 - acc: 0.3147 - val_loss: 1.7812 - val_acc: 0.3823
# Epoch 4/30
# 50000/50000 [==============================] - 21s 412us/step - loss: 1.7866 - acc: 0.3567 - val_loss: 1.6918 - val_acc: 0.3989
# Epoch 5/30
# 50000/50000 [==============================] - 20s 409us/step - loss: 1.7145 - acc: 0.3800 - val_loss: 1.6290 - val_acc: 0.4175
# Epoch 6/30
# 50000/50000 [==============================] - 20s 407us/step - loss: 1.6641 - acc: 0.3933 - val_loss: 1.5845 - val_acc: 0.4298
# Epoch 7/30
# 50000/50000 [==============================] - 22s 434us/step - loss: 1.6190 - acc: 0.4073 - val_loss: 1.5381 - val_acc: 0.4420
# Epoch 8/30
# 50000/50000 [==============================] - 22s 438us/step - loss: 1.5844 - acc: 0.4184 - val_loss: 1.5034 - val_acc: 0.4563
# Epoch 9/30
# 50000/50000 [==============================] - 21s 427us/step - loss: 1.5509 - acc: 0.4321 - val_loss: 1.4874 - val_acc: 0.4627
# Epoch 10/30
# 50000/50000 [==============================] - 21s 410us/step - loss: 1.5265 - acc: 0.4389 - val_loss: 1.4610 - val_acc: 0.4702
# Epoch 11/30
# 50000/50000 [==============================] - 21s 411us/step - loss: 1.5032 - acc: 0.4529 - val_loss: 1.4431 - val_acc: 0.4771
# Epoch 12/30
# 50000/50000 [==============================] - 21s 412us/step - loss: 1.4862 - acc: 0.4592 - val_loss: 1.4123 - val_acc: 0.4934
# Epoch 13/30
# 50000/50000 [==============================] - 21s 412us/step - loss: 1.4630 - acc: 0.4696 - val_loss: 1.4021 - val_acc: 0.4950
# Epoch 14/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.4489 - acc: 0.4712 - val_loss: 1.3869 - val_acc: 0.5020
# Epoch 15/30
# 50000/50000 [==============================] - 21s 414us/step - loss: 1.4322 - acc: 0.4823 - val_loss: 1.3710 - val_acc: 0.5105
# Epoch 16/30
# 50000/50000 [==============================] - 20s 404us/step - loss: 1.4182 - acc: 0.4872 - val_loss: 1.3646 - val_acc: 0.5067
# Epoch 17/30
# 50000/50000 [==============================] - 20s 401us/step - loss: 1.4037 - acc: 0.4927 - val_loss: 1.3529 - val_acc: 0.5134
# Epoch 18/30
# 50000/50000 [==============================] - 20s 400us/step - loss: 1.3883 - acc: 0.4997 - val_loss: 1.3434 - val_acc: 0.5194
# Epoch 19/30
# 50000/50000 [==============================] - 20s 397us/step - loss: 1.3769 - acc: 0.5044 - val_loss: 1.3100 - val_acc: 0.5322
# Epoch 20/30
# 50000/50000 [==============================] - 20s 397us/step - loss: 1.3640 - acc: 0.5086 - val_loss: 1.3087 - val_acc: 0.5317
# Epoch 21/30
# 50000/50000 [==============================] - 20s 401us/step - loss: 1.3496 - acc: 0.5137 - val_loss: 1.2895 - val_acc: 0.5427
# Epoch 22/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 1.3388 - acc: 0.5203 - val_loss: 1.2821 - val_acc: 0.5430
# Epoch 23/30
# 50000/50000 [==============================] - 20s 407us/step - loss: 1.3269 - acc: 0.5249 - val_loss: 1.2823 - val_acc: 0.5428
# Epoch 24/30
# 50000/50000 [==============================] - 20s 404us/step - loss: 1.3163 - acc: 0.5286 - val_loss: 1.2624 - val_acc: 0.5529
# Epoch 25/30
# 50000/50000 [==============================] - 20s 407us/step - loss: 1.3072 - acc: 0.5319 - val_loss: 1.2438 - val_acc: 0.5601
# Epoch 26/30
# 50000/50000 [==============================] - 20s 409us/step - loss: 1.2979 - acc: 0.5375 - val_loss: 1.2390 - val_acc: 0.5633
# Epoch 27/30
# 50000/50000 [==============================] - 20s 410us/step - loss: 1.2855 - acc: 0.5421 - val_loss: 1.2243 - val_acc: 0.5674
# Epoch 28/30
# 50000/50000 [==============================] - 20s 406us/step - loss: 1.2766 - acc: 0.5453 - val_loss: 1.2172 - val_acc: 0.5690
# Epoch 29/30
# 50000/50000 [==============================] - 21s 411us/step - loss: 1.2685 - acc: 0.5509 - val_loss: 1.2084 - val_acc: 0.5756
# Epoch 30/30
# 50000/50000 [==============================] - 20s 403us/step - loss: 1.2588 - acc: 0.5513 - val_loss: 1.2051 - val_acc: 0.5757
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 1s 126us/step
# Test loss: 1.205130485534668
# Test accuracy: 0.5757

# %% [markdown]
# activition = sigmoid

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('sigmoid'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('sigmoid'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 22s 439us/step - loss: 2.3311 - acc: 0.1013 - val_loss: 2.3041 - val_acc: 0.1000
# Epoch 2/30
# 50000/50000 [==============================] - 21s 415us/step - loss: 2.3075 - acc: 0.0997 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 3/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 2.3069 - acc: 0.0987 - val_loss: 2.3032 - val_acc: 0.1000
# Epoch 4/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 2.3065 - acc: 0.0984 - val_loss: 2.3032 - val_acc: 0.1000
# Epoch 5/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 2.3053 - acc: 0.0981 - val_loss: 2.3028 - val_acc: 0.1000
# Epoch 6/30
# 50000/50000 [==============================] - 20s 406us/step - loss: 2.3051 - acc: 0.1007 - val_loss: 2.3027 - val_acc: 0.1000
# Epoch 7/30
# 50000/50000 [==============================] - 20s 405us/step - loss: 2.3047 - acc: 0.1001 - val_loss: 2.3028 - val_acc: 0.1000
# Epoch 8/30
# 50000/50000 [==============================] - 20s 405us/step - loss: 2.3046 - acc: 0.0968 - val_loss: 2.3030 - val_acc: 0.1000
# Epoch 9/30
# 50000/50000 [==============================] - 20s 406us/step - loss: 2.2638 - acc: 0.1330 - val_loss: 2.1095 - val_acc: 0.2381
# Epoch 10/30
# 50000/50000 [==============================] - 20s 408us/step - loss: 2.0915 - acc: 0.2277 - val_loss: 2.0043 - val_acc: 0.2710
# Epoch 11/30
# 50000/50000 [==============================] - 20s 410us/step - loss: 2.0153 - acc: 0.2639 - val_loss: 1.9541 - val_acc: 0.2965
# Epoch 12/30
# 50000/50000 [==============================] - 21s 421us/step - loss: 1.9673 - acc: 0.2802 - val_loss: 1.8998 - val_acc: 0.3177
# Epoch 13/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 1.9310 - acc: 0.2948 - val_loss: 1.8672 - val_acc: 0.3216
# Epoch 14/30
# 50000/50000 [==============================] - 21s 413us/step - loss: 1.9039 - acc: 0.3067 - val_loss: 1.8295 - val_acc: 0.3430
# Epoch 15/30
# 50000/50000 [==============================] - 21s 412us/step - loss: 1.8804 - acc: 0.3162 - val_loss: 1.8150 - val_acc: 0.3481
# Epoch 16/30
# 50000/50000 [==============================] - 20s 410us/step - loss: 1.8568 - acc: 0.3228 - val_loss: 1.7793 - val_acc: 0.3590
# Epoch 17/30
# 50000/50000 [==============================] - 21s 411us/step - loss: 1.8355 - acc: 0.3346 - val_loss: 1.7644 - val_acc: 0.3646
# Epoch 18/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 1.8160 - acc: 0.3422 - val_loss: 1.7460 - val_acc: 0.3705
# Epoch 19/30
# 50000/50000 [==============================] - 20s 408us/step - loss: 1.7982 - acc: 0.3507 - val_loss: 1.7139 - val_acc: 0.3810
# Epoch 20/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.7724 - acc: 0.3582 - val_loss: 1.6851 - val_acc: 0.3921
# Epoch 21/30
# 50000/50000 [==============================] - 21s 413us/step - loss: 1.7525 - acc: 0.3668 - val_loss: 1.6723 - val_acc: 0.4037
# Epoch 22/30
# 50000/50000 [==============================] - 22s 435us/step - loss: 1.7313 - acc: 0.3755 - val_loss: 1.6403 - val_acc: 0.4118
# Epoch 23/30
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.7043 - acc: 0.3852 - val_loss: 1.6313 - val_acc: 0.4093
# Epoch 24/30
# 50000/50000 [==============================] - 22s 432us/step - loss: 1.6847 - acc: 0.3914 - val_loss: 1.6242 - val_acc: 0.4108
# Epoch 25/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.6656 - acc: 0.3987 - val_loss: 1.6027 - val_acc: 0.4216
# Epoch 26/30
# 50000/50000 [==============================] - 21s 413us/step - loss: 1.6530 - acc: 0.4022 - val_loss: 1.5804 - val_acc: 0.4318
# Epoch 27/30
# 50000/50000 [==============================] - 20s 408us/step - loss: 1.6361 - acc: 0.4085 - val_loss: 1.5499 - val_acc: 0.4379
# Epoch 28/30
# 50000/50000 [==============================] - 20s 403us/step - loss: 1.6209 - acc: 0.4152 - val_loss: 1.5389 - val_acc: 0.4456
# Epoch 29/30
# 50000/50000 [==============================] - 20s 405us/step - loss: 1.6033 - acc: 0.4243 - val_loss: 1.5248 - val_acc: 0.4474
# Epoch 30/30
# 50000/50000 [==============================] - 20s 403us/step - loss: 1.5849 - acc: 0.4291 - val_loss: 1.5094 - val_acc: 0.4520
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 1s 129us/step
# Test loss: 1.5094450645446778
# Test accuracy: 0.452

# %% [markdown]
# activition = tanh

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('tanh'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('tanh'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 23s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 27s 537us/step - loss: 1.6786 - acc: 0.3988 - val_loss: 1.4224 - val_acc: 0.4941
# Epoch 2/30
# 50000/50000 [==============================] - 21s 428us/step - loss: 1.3843 - acc: 0.5115 - val_loss: 1.3150 - val_acc: 0.5391
# Epoch 3/30
# 50000/50000 [==============================] - 21s 418us/step - loss: 1.2667 - acc: 0.5579 - val_loss: 1.2210 - val_acc: 0.5738
# Epoch 4/30
# 50000/50000 [==============================] - 21s 422us/step - loss: 1.1862 - acc: 0.5870 - val_loss: 1.1727 - val_acc: 0.5919
# Epoch 5/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.1372 - acc: 0.6072 - val_loss: 1.1221 - val_acc: 0.6076
# Epoch 6/30
# 50000/50000 [==============================] - 21s 415us/step - loss: 1.0965 - acc: 0.6208 - val_loss: 1.0331 - val_acc: 0.6463
# Epoch 7/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 1.0702 - acc: 0.6306 - val_loss: 1.0298 - val_acc: 0.6467
# Epoch 8/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 1.0432 - acc: 0.6415 - val_loss: 1.1437 - val_acc: 0.6057
# Epoch 9/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 1.0201 - acc: 0.6498 - val_loss: 1.0749 - val_acc: 0.6300
# Epoch 10/30
# 50000/50000 [==============================] - 21s 423us/step - loss: 1.0079 - acc: 0.6543 - val_loss: 1.0345 - val_acc: 0.6422
# Epoch 11/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 0.9882 - acc: 0.6589 - val_loss: 0.9692 - val_acc: 0.6670
# Epoch 12/30
# 50000/50000 [==============================] - 21s 414us/step - loss: 0.9738 - acc: 0.6644 - val_loss: 0.9647 - val_acc: 0.6652
# Epoch 13/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 0.9608 - acc: 0.6685 - val_loss: 0.9694 - val_acc: 0.6666
# Epoch 14/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 0.9524 - acc: 0.6701 - val_loss: 0.9449 - val_acc: 0.6778
# Epoch 15/30
# 50000/50000 [==============================] - 21s 414us/step - loss: 0.9381 - acc: 0.6769 - val_loss: 0.9536 - val_acc: 0.6688
# Epoch 16/30
# 50000/50000 [==============================] - 21s 422us/step - loss: 0.9303 - acc: 0.6807 - val_loss: 0.9221 - val_acc: 0.6847
# Epoch 17/30
# 50000/50000 [==============================] - 21s 415us/step - loss: 0.9138 - acc: 0.6857 - val_loss: 0.9310 - val_acc: 0.6809
# Epoch 18/30
# 50000/50000 [==============================] - 21s 416us/step - loss: 0.9044 - acc: 0.6883 - val_loss: 0.9004 - val_acc: 0.6912
# Epoch 19/30
# 50000/50000 [==============================] - 20s 410us/step - loss: 0.8976 - acc: 0.6897 - val_loss: 0.9034 - val_acc: 0.6893
# Epoch 20/30
# 50000/50000 [==============================] - 21s 411us/step - loss: 0.8887 - acc: 0.6923 - val_loss: 0.8944 - val_acc: 0.6937
# Epoch 21/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 0.8764 - acc: 0.6968 - val_loss: 0.8788 - val_acc: 0.7015
# Epoch 22/30
# 50000/50000 [==============================] - 20s 395us/step - loss: 0.8657 - acc: 0.7003 - val_loss: 0.8844 - val_acc: 0.6936
# Epoch 23/30
# 50000/50000 [==============================] - 20s 393us/step - loss: 0.8562 - acc: 0.7015 - val_loss: 0.8808 - val_acc: 0.6974
# Epoch 24/30
# 50000/50000 [==============================] - 20s 394us/step - loss: 0.8483 - acc: 0.7059 - val_loss: 0.8896 - val_acc: 0.6946
# Epoch 25/30
# 50000/50000 [==============================] - 20s 400us/step - loss: 0.8374 - acc: 0.7104 - val_loss: 0.8550 - val_acc: 0.7103
# Epoch 26/30
# 50000/50000 [==============================] - 20s 397us/step - loss: 0.8327 - acc: 0.7116 - val_loss: 0.8480 - val_acc: 0.7098
# Epoch 27/30
# 50000/50000 [==============================] - 20s 401us/step - loss: 0.8233 - acc: 0.7140 - val_loss: 0.8667 - val_acc: 0.7029
# Epoch 28/30
# 50000/50000 [==============================] - 20s 399us/step - loss: 0.8097 - acc: 0.7199 - val_loss: 0.8423 - val_acc: 0.7104
# Epoch 29/30
# 50000/50000 [==============================] - 20s 399us/step - loss: 0.8000 - acc: 0.7209 - val_loss: 0.8447 - val_acc: 0.7091
# Epoch 30/30
# 50000/50000 [==============================] - 20s 398us/step - loss: 0.7921 - acc: 0.7246 - val_loss: 0.8486 - val_acc: 0.7089
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 1s 124us/step
# Test loss: 0.8486415269851685
# Test accuracy: 0.7089

# %% [markdown]
# activition = elu

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('elu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('elu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 21s 427us/step - loss: 1.6853 - acc: 0.3994 - val_loss: 1.4261 - val_acc: 0.4895
# Epoch 2/30
# 50000/50000 [==============================] - 20s 409us/step - loss: 1.3759 - acc: 0.5169 - val_loss: 1.2984 - val_acc: 0.5311
# Epoch 3/30
# 50000/50000 [==============================] - 21s 410us/step - loss: 1.2447 - acc: 0.5654 - val_loss: 1.1625 - val_acc: 0.5935
# Epoch 4/30
# 50000/50000 [==============================] - 20s 410us/step - loss: 1.1675 - acc: 0.5957 - val_loss: 1.1730 - val_acc: 0.5848
# Epoch 5/30
# 50000/50000 [==============================] - 24s 483us/step - loss: 1.1181 - acc: 0.6136 - val_loss: 1.0890 - val_acc: 0.6243
# Epoch 6/30
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.0759 - acc: 0.6275 - val_loss: 1.0761 - val_acc: 0.6259
# Epoch 7/30
# 50000/50000 [==============================] - 22s 443us/step - loss: 1.0460 - acc: 0.6398 - val_loss: 1.0049 - val_acc: 0.6536
# Epoch 8/30
# 50000/50000 [==============================] - 21s 415us/step - loss: 1.0205 - acc: 0.6481 - val_loss: 1.0409 - val_acc: 0.6420
# Epoch 9/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 1.0021 - acc: 0.6548 - val_loss: 0.9859 - val_acc: 0.6596
# Epoch 10/30
# 50000/50000 [==============================] - 21s 421us/step - loss: 0.9805 - acc: 0.6609 - val_loss: 0.9601 - val_acc: 0.6679
# Epoch 11/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 0.9622 - acc: 0.6671 - val_loss: 0.9205 - val_acc: 0.6859
# Epoch 12/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 0.9396 - acc: 0.6779 - val_loss: 0.9354 - val_acc: 0.6813
# Epoch 13/30
# 50000/50000 [==============================] - 21s 420us/step - loss: 0.9273 - acc: 0.6805 - val_loss: 0.9227 - val_acc: 0.6822
# Epoch 14/30
# 50000/50000 [==============================] - 21s 415us/step - loss: 0.9107 - acc: 0.6853 - val_loss: 0.9001 - val_acc: 0.6935
# Epoch 15/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 0.8964 - acc: 0.6922 - val_loss: 0.8710 - val_acc: 0.7027
# Epoch 16/30
# 50000/50000 [==============================] - 21s 413us/step - loss: 0.8814 - acc: 0.6955 - val_loss: 0.8509 - val_acc: 0.7122
# Epoch 17/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 0.8637 - acc: 0.7024 - val_loss: 0.8600 - val_acc: 0.7061
# Epoch 18/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 0.8524 - acc: 0.7056 - val_loss: 0.8314 - val_acc: 0.7171
# Epoch 19/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 0.8376 - acc: 0.7125 - val_loss: 0.8408 - val_acc: 0.7097
# Epoch 20/30
# 50000/50000 [==============================] - 22s 432us/step - loss: 0.8234 - acc: 0.7142 - val_loss: 0.8224 - val_acc: 0.7190
# Epoch 21/30
# 50000/50000 [==============================] - 20s 405us/step - loss: 0.8100 - acc: 0.7208 - val_loss: 0.8208 - val_acc: 0.7170
# Epoch 22/30
# 50000/50000 [==============================] - 20s 401us/step - loss: 0.7986 - acc: 0.7217 - val_loss: 0.8023 - val_acc: 0.7267
# Epoch 23/30
# 50000/50000 [==============================] - 20s 396us/step - loss: 0.7844 - acc: 0.7263 - val_loss: 0.7917 - val_acc: 0.7316
# Epoch 24/30
# 50000/50000 [==============================] - 20s 397us/step - loss: 0.7709 - acc: 0.7315 - val_loss: 0.7884 - val_acc: 0.7314
# Epoch 25/30
# 50000/50000 [==============================] - 20s 400us/step - loss: 0.7576 - acc: 0.7357 - val_loss: 0.7412 - val_acc: 0.7456
# Epoch 26/30
# 50000/50000 [==============================] - 20s 402us/step - loss: 0.7381 - acc: 0.7433 - val_loss: 0.7384 - val_acc: 0.7432
# Epoch 27/30
# 50000/50000 [==============================] - 20s 403us/step - loss: 0.7251 - acc: 0.7457 - val_loss: 0.7219 - val_acc: 0.7545
# Epoch 28/30
# 50000/50000 [==============================] - 20s 403us/step - loss: 0.7096 - acc: 0.7526 - val_loss: 0.7232 - val_acc: 0.7502
# Epoch 29/30
# 50000/50000 [==============================] - 20s 409us/step - loss: 0.6961 - acc: 0.7582 - val_loss: 0.7030 - val_acc: 0.7609
# Epoch 30/30
# 50000/50000 [==============================] - 20s 402us/step - loss: 0.6841 - acc: 0.7638 - val_loss: 0.7075 - val_acc: 0.7563
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 1s 126us/step
# Test loss: 0.7074624791622162
# Test accuracy: 0.7563

# %% [markdown]
# activition = selu

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('selu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('selu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('selu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('selu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('selu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 25s 503us/step - loss: 1.6737 - acc: 0.4057 - val_loss: 1.5344 - val_acc: 0.4596
# Epoch 2/30
# 50000/50000 [==============================] - 25s 504us/step - loss: 1.3616 - acc: 0.5233 - val_loss: 1.2645 - val_acc: 0.5682
# Epoch 3/30
# 50000/50000 [==============================] - 25s 497us/step - loss: 1.2393 - acc: 0.5675 - val_loss: 1.2213 - val_acc: 0.5710
# Epoch 4/30
# 50000/50000 [==============================] - 25s 495us/step - loss: 1.1688 - acc: 0.5958 - val_loss: 1.1276 - val_acc: 0.6152
# Epoch 5/30
# 50000/50000 [==============================] - 25s 502us/step - loss: 1.1190 - acc: 0.6109 - val_loss: 1.1727 - val_acc: 0.5917
# Epoch 6/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 1.0829 - acc: 0.6252 - val_loss: 1.0804 - val_acc: 0.6272
# Epoch 7/30
# 50000/50000 [==============================] - 25s 497us/step - loss: 1.0535 - acc: 0.6346 - val_loss: 1.0186 - val_acc: 0.6510
# Epoch 8/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 1.0305 - acc: 0.6441 - val_loss: 1.0471 - val_acc: 0.6396
# Epoch 9/30
# 50000/50000 [==============================] - 25s 497us/step - loss: 1.0116 - acc: 0.6498 - val_loss: 0.9784 - val_acc: 0.6693
# Epoch 10/30
# 50000/50000 [==============================] - 25s 500us/step - loss: 0.9896 - acc: 0.6561 - val_loss: 1.0201 - val_acc: 0.6506
# Epoch 11/30
# 50000/50000 [==============================] - 25s 501us/step - loss: 0.9744 - acc: 0.6630 - val_loss: 0.9978 - val_acc: 0.6604
# Epoch 12/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 0.9594 - acc: 0.6673 - val_loss: 0.9688 - val_acc: 0.6681
# Epoch 13/30
# 50000/50000 [==============================] - 25s 500us/step - loss: 0.9451 - acc: 0.6732 - val_loss: 1.0026 - val_acc: 0.6526
# Epoch 14/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 0.9285 - acc: 0.6781 - val_loss: 1.0499 - val_acc: 0.6365
# Epoch 15/30
# 50000/50000 [==============================] - 25s 500us/step - loss: 0.9211 - acc: 0.6794 - val_loss: 0.9834 - val_acc: 0.6614
# Epoch 16/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 0.9047 - acc: 0.6861 - val_loss: 0.9600 - val_acc: 0.6737
# Epoch 17/30
# 50000/50000 [==============================] - 25s 502us/step - loss: 0.8976 - acc: 0.6877 - val_loss: 1.0269 - val_acc: 0.6487
# Epoch 18/30
# 50000/50000 [==============================] - 25s 503us/step - loss: 0.8836 - acc: 0.6935 - val_loss: 0.9703 - val_acc: 0.6636
# Epoch 19/30
# 50000/50000 [==============================] - 25s 497us/step - loss: 0.8740 - acc: 0.6978 - val_loss: 0.9367 - val_acc: 0.6753
# Epoch 20/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 0.8678 - acc: 0.6997 - val_loss: 0.9448 - val_acc: 0.6753
# Epoch 21/30
# 50000/50000 [==============================] - 25s 499us/step - loss: 0.8601 - acc: 0.7034 - val_loss: 0.9943 - val_acc: 0.6533
# Epoch 22/30
# 50000/50000 [==============================] - 26s 523us/step - loss: 0.8546 - acc: 0.7058 - val_loss: 0.8917 - val_acc: 0.6940
# Epoch 23/30
# 50000/50000 [==============================] - 29s 583us/step - loss: 0.8399 - acc: 0.7100 - val_loss: 0.9492 - val_acc: 0.6740
# Epoch 24/30
# 50000/50000 [==============================] - 27s 541us/step - loss: 0.8356 - acc: 0.7077 - val_loss: 0.8986 - val_acc: 0.6914
# Epoch 25/30
# 50000/50000 [==============================] - 26s 516us/step - loss: 0.8264 - acc: 0.7141 - val_loss: 0.9765 - val_acc: 0.6637
# Epoch 26/30
# 50000/50000 [==============================] - 27s 531us/step - loss: 0.8186 - acc: 0.7145 - val_loss: 0.8986 - val_acc: 0.6959
# Epoch 27/30
# 50000/50000 [==============================] - 26s 528us/step - loss: 0.8135 - acc: 0.7170 - val_loss: 0.8695 - val_acc: 0.7033
# Epoch 28/30
# 50000/50000 [==============================] - 26s 527us/step - loss: 0.8076 - acc: 0.7203 - val_loss: 0.9068 - val_acc: 0.6888
# Epoch 29/30
# 50000/50000 [==============================] - 26s 530us/step - loss: 0.8038 - acc: 0.7210 - val_loss: 0.9077 - val_acc: 0.6903
# Epoch 30/30
# 50000/50000 [==============================] - 26s 525us/step - loss: 0.7943 - acc: 0.7250 - val_loss: 0.8912 - val_acc: 0.6936
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 2s 162us/step
# Test loss: 0.8911828641891479
# Test accuracy: 0.6936

# %% [markdown]
# activition = softplus

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('softplus'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('softplus'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('softplus'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('softplus'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('softplus'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 25s 508us/step - loss: 2.3444 - acc: 0.1006 - val_loss: 2.2890 - val_acc: 0.1126
# Epoch 2/30
# 50000/50000 [==============================] - 24s 486us/step - loss: 2.1462 - acc: 0.2108 - val_loss: 2.0446 - val_acc: 0.2595
# Epoch 3/30
# 50000/50000 [==============================] - 24s 483us/step - loss: 2.0173 - acc: 0.2743 - val_loss: 1.9056 - val_acc: 0.3298
# Epoch 4/30
# 50000/50000 [==============================] - 23s 466us/step - loss: 1.9529 - acc: 0.3004 - val_loss: 1.8276 - val_acc: 0.3458
# Epoch 5/30
# 50000/50000 [==============================] - 23s 458us/step - loss: 1.8792 - acc: 0.3256 - val_loss: 1.8182 - val_acc: 0.3561
# Epoch 6/30
# 50000/50000 [==============================] - 22s 448us/step - loss: 1.7994 - acc: 0.3548 - val_loss: 1.6806 - val_acc: 0.4014
# Epoch 7/30
# 50000/50000 [==============================] - 22s 447us/step - loss: 1.7307 - acc: 0.3808 - val_loss: 1.6070 - val_acc: 0.4210
# Epoch 8/30
# 50000/50000 [==============================] - 22s 435us/step - loss: 1.6761 - acc: 0.4000 - val_loss: 1.6040 - val_acc: 0.4325
# Epoch 9/30
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.6346 - acc: 0.4202 - val_loss: 1.5289 - val_acc: 0.4605
# Epoch 10/30
# 50000/50000 [==============================] - 22s 444us/step - loss: 1.6039 - acc: 0.4301 - val_loss: 1.5410 - val_acc: 0.4736
# Epoch 11/30
# 50000/50000 [==============================] - 23s 457us/step - loss: 1.5790 - acc: 0.4406 - val_loss: 1.4455 - val_acc: 0.4955
# Epoch 12/30
# 50000/50000 [==============================] - 23s 450us/step - loss: 1.5563 - acc: 0.4488 - val_loss: 1.4574 - val_acc: 0.4960
# Epoch 13/30
# 50000/50000 [==============================] - 22s 439us/step - loss: 1.5404 - acc: 0.4545 - val_loss: 1.4189 - val_acc: 0.4995
# Epoch 14/30
# 50000/50000 [==============================] - 22s 438us/step - loss: 1.5287 - acc: 0.4577 - val_loss: 1.4256 - val_acc: 0.5012
# Epoch 15/30
# 50000/50000 [==============================] - 21s 422us/step - loss: 1.5078 - acc: 0.4681 - val_loss: 1.4204 - val_acc: 0.5204
# Epoch 16/30
# 50000/50000 [==============================] - 21s 417us/step - loss: 1.4996 - acc: 0.4675 - val_loss: 1.3747 - val_acc: 0.5192
# Epoch 17/30
# 50000/50000 [==============================] - 21s 422us/step - loss: 1.4889 - acc: 0.4757 - val_loss: 1.3920 - val_acc: 0.5034
# Epoch 18/30
# 50000/50000 [==============================] - 21s 421us/step - loss: 1.4786 - acc: 0.4771 - val_loss: 1.3530 - val_acc: 0.5291
# Epoch 19/30
# 50000/50000 [==============================] - 21s 421us/step - loss: 1.4716 - acc: 0.4803 - val_loss: 1.3623 - val_acc: 0.5292
# Epoch 20/30
# 50000/50000 [==============================] - 22s 431us/step - loss: 1.4623 - acc: 0.4852 - val_loss: 1.3494 - val_acc: 0.5321
# Epoch 21/30
# 50000/50000 [==============================] - 22s 432us/step - loss: 1.4513 - acc: 0.4864 - val_loss: 1.4423 - val_acc: 0.5287
# Epoch 22/30
# 50000/50000 [==============================] - 21s 427us/step - loss: 1.4488 - acc: 0.4887 - val_loss: 1.3488 - val_acc: 0.5272
# Epoch 23/30
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.4428 - acc: 0.4944 - val_loss: 1.3380 - val_acc: 0.5354
# Epoch 24/30
# 50000/50000 [==============================] - 21s 425us/step - loss: 1.4384 - acc: 0.4930 - val_loss: 1.3524 - val_acc: 0.5389
# Epoch 25/30
# 50000/50000 [==============================] - 21s 419us/step - loss: 1.4311 - acc: 0.4954 - val_loss: 1.3465 - val_acc: 0.5509
# Epoch 26/30
# 50000/50000 [==============================] - 21s 426us/step - loss: 1.4316 - acc: 0.4987 - val_loss: 1.3170 - val_acc: 0.5351
# Epoch 27/30
# 50000/50000 [==============================] - 22s 435us/step - loss: 1.4251 - acc: 0.5020 - val_loss: 1.3508 - val_acc: 0.5416
# Epoch 28/30
# 50000/50000 [==============================] - 22s 441us/step - loss: 1.4265 - acc: 0.5006 - val_loss: 1.3199 - val_acc: 0.5494
# Epoch 29/30
# 50000/50000 [==============================] - 25s 501us/step - loss: 1.4163 - acc: 0.5028 - val_loss: 1.3825 - val_acc: 0.5431
# Epoch 30/30
# 50000/50000 [==============================] - 23s 454us/step - loss: 1.4174 - acc: 0.5049 - val_loss: 1.3238 - val_acc: 0.5543
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 1s 148us/step
# Test loss: 1.3238357486724854
# Test accuracy: 0.5543

# %% [markdown]
# activition = softsign

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 32
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('softsign'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('softsign'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('softsign'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('softsign'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('softsign'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 28s 557us/step - loss: 1.6724 - acc: 0.3987 - val_loss: 1.4877 - val_acc: 0.4629
# Epoch 2/30
# 50000/50000 [==============================] - 24s 476us/step - loss: 1.3853 - acc: 0.5077 - val_loss: 1.3143 - val_acc: 0.5339
# Epoch 3/30
# 50000/50000 [==============================] - 23s 463us/step - loss: 1.2485 - acc: 0.5614 - val_loss: 1.1648 - val_acc: 0.5915
# Epoch 4/30
# 50000/50000 [==============================] - 23s 460us/step - loss: 1.1503 - acc: 0.5951 - val_loss: 1.0722 - val_acc: 0.6252
# Epoch 5/30
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.0936 - acc: 0.6162 - val_loss: 1.0389 - val_acc: 0.6441
# Epoch 6/30
# 50000/50000 [==============================] - 22s 445us/step - loss: 1.0567 - acc: 0.6328 - val_loss: 1.0106 - val_acc: 0.6493
# Epoch 7/30
# 50000/50000 [==============================] - 22s 437us/step - loss: 1.0274 - acc: 0.6434 - val_loss: 1.0137 - val_acc: 0.6522
# Epoch 8/30
# 50000/50000 [==============================] - 22s 440us/step - loss: 1.0051 - acc: 0.6510 - val_loss: 0.9750 - val_acc: 0.6634
# Epoch 9/30
# 50000/50000 [==============================] - 22s 441us/step - loss: 0.9829 - acc: 0.6596 - val_loss: 0.9686 - val_acc: 0.6697
# Epoch 10/30
# 50000/50000 [==============================] - 22s 445us/step - loss: 0.9612 - acc: 0.6686 - val_loss: 0.9246 - val_acc: 0.6831
# Epoch 11/30
# 50000/50000 [==============================] - 23s 460us/step - loss: 0.9473 - acc: 0.6699 - val_loss: 0.9089 - val_acc: 0.6885
# Epoch 12/30
# 50000/50000 [==============================] - 23s 458us/step - loss: 0.9262 - acc: 0.6790 - val_loss: 0.8913 - val_acc: 0.6932
# Epoch 13/30
# 50000/50000 [==============================] - 23s 463us/step - loss: 0.9108 - acc: 0.6850 - val_loss: 0.8712 - val_acc: 0.7009
# Epoch 14/30
# 50000/50000 [==============================] - 23s 451us/step - loss: 0.8951 - acc: 0.6899 - val_loss: 0.8900 - val_acc: 0.6947
# Epoch 15/30
# 50000/50000 [==============================] - 23s 451us/step - loss: 0.8817 - acc: 0.6946 - val_loss: 0.8518 - val_acc: 0.7073
# Epoch 16/30
# 50000/50000 [==============================] - 23s 464us/step - loss: 0.8691 - acc: 0.6993 - val_loss: 0.8424 - val_acc: 0.7130
# Epoch 17/30
# 50000/50000 [==============================] - 22s 446us/step - loss: 0.8594 - acc: 0.7005 - val_loss: 0.8408 - val_acc: 0.7141
# Epoch 18/30
# 50000/50000 [==============================] - 23s 452us/step - loss: 0.8445 - acc: 0.7064 - val_loss: 0.8314 - val_acc: 0.7123
# Epoch 19/30
# 50000/50000 [==============================] - 23s 454us/step - loss: 0.8346 - acc: 0.7099 - val_loss: 0.8220 - val_acc: 0.7165
# Epoch 20/30
# 50000/50000 [==============================] - 23s 455us/step - loss: 0.8241 - acc: 0.7134 - val_loss: 0.8124 - val_acc: 0.7228
# Epoch 21/30
# 50000/50000 [==============================] - 24s 474us/step - loss: 0.8140 - acc: 0.7196 - val_loss: 0.7825 - val_acc: 0.7283
# Epoch 22/30
# 50000/50000 [==============================] - 24s 472us/step - loss: 0.8040 - acc: 0.7213 - val_loss: 0.8090 - val_acc: 0.7224
# Epoch 23/30
# 50000/50000 [==============================] - 23s 460us/step - loss: 0.7922 - acc: 0.7253 - val_loss: 0.7806 - val_acc: 0.7311
# Epoch 24/30
# 50000/50000 [==============================] - 23s 454us/step - loss: 0.7866 - acc: 0.7248 - val_loss: 0.7687 - val_acc: 0.7348
# Epoch 25/30
# 50000/50000 [==============================] - 24s 477us/step - loss: 0.7781 - acc: 0.7276 - val_loss: 0.7844 - val_acc: 0.7296
# Epoch 26/30
# 50000/50000 [==============================] - 24s 485us/step - loss: 0.7658 - acc: 0.7348 - val_loss: 0.7769 - val_acc: 0.7339
# Epoch 27/30
# 50000/50000 [==============================] - 23s 467us/step - loss: 0.7597 - acc: 0.7369 - val_loss: 0.7784 - val_acc: 0.7304
# Epoch 28/30
# 50000/50000 [==============================] - 23s 459us/step - loss: 0.7495 - acc: 0.7388 - val_loss: 0.7467 - val_acc: 0.7428
# Epoch 29/30
# 50000/50000 [==============================] - 24s 488us/step - loss: 0.7410 - acc: 0.7413 - val_loss: 0.7599 - val_acc: 0.7369
# Epoch 30/30
# 50000/50000 [==============================] - 27s 542us/step - loss: 0.7322 - acc: 0.7445 - val_loss: 0.7412 - val_acc: 0.7417
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 2s 195us/step
# Test loss: 0.7411663712501526
# Test accuracy: 0.7417

# %% [markdown]
# batch size = 16

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt

batch_size = 16
num_classes = 10
epochs = 30
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    h=model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 39s 773us/step - loss: 1.7868 - acc: 0.3496 - val_loss: 1.4690 - val_acc: 0.4677
# Epoch 2/30
# 50000/50000 [==============================] - 37s 747us/step - loss: 1.4339 - acc: 0.4833 - val_loss: 1.2580 - val_acc: 0.5500
# Epoch 3/30
# 50000/50000 [==============================] - 38s 762us/step - loss: 1.2775 - acc: 0.5448 - val_loss: 1.1779 - val_acc: 0.5868
# Epoch 4/30
# 50000/50000 [==============================] - 40s 791us/step - loss: 1.1736 - acc: 0.5853 - val_loss: 1.0663 - val_acc: 0.6239
# Epoch 5/30
# 50000/50000 [==============================] - 36s 723us/step - loss: 1.0916 - acc: 0.6177 - val_loss: 1.0029 - val_acc: 0.6480
# Epoch 6/30
# 50000/50000 [==============================] - 37s 731us/step - loss: 1.0346 - acc: 0.6385 - val_loss: 0.9502 - val_acc: 0.6702
# Epoch 7/30
# 50000/50000 [==============================] - 41s 811us/step - loss: 0.9847 - acc: 0.6565 - val_loss: 0.9012 - val_acc: 0.6859
# Epoch 8/30
# 50000/50000 [==============================] - 39s 784us/step - loss: 0.9390 - acc: 0.6733 - val_loss: 0.8981 - val_acc: 0.6866
# Epoch 9/30
# 50000/50000 [==============================] - 37s 747us/step - loss: 0.9053 - acc: 0.6852 - val_loss: 0.8603 - val_acc: 0.7033
# Epoch 10/30
# 50000/50000 [==============================] - 38s 759us/step - loss: 0.8797 - acc: 0.6965 - val_loss: 0.8394 - val_acc: 0.7062
# Epoch 11/30
# 50000/50000 [==============================] - 39s 781us/step - loss: 0.8609 - acc: 0.7030 - val_loss: 0.8179 - val_acc: 0.7202
# Epoch 12/30
# 50000/50000 [==============================] - 37s 738us/step - loss: 0.8380 - acc: 0.7113 - val_loss: 0.8196 - val_acc: 0.7187
# Epoch 13/30
# 50000/50000 [==============================] - 38s 762us/step - loss: 0.8194 - acc: 0.7188 - val_loss: 0.8129 - val_acc: 0.7202
# Epoch 14/30
# 50000/50000 [==============================] - 38s 763us/step - loss: 0.8040 - acc: 0.7222 - val_loss: 0.7790 - val_acc: 0.7352
# Epoch 15/30
# 50000/50000 [==============================] - 39s 786us/step - loss: 0.7978 - acc: 0.7272 - val_loss: 0.7664 - val_acc: 0.7402
# Epoch 16/30
# 50000/50000 [==============================] - 39s 785us/step - loss: 0.7866 - acc: 0.7331 - val_loss: 0.7587 - val_acc: 0.7391
# Epoch 17/30
# 50000/50000 [==============================] - 39s 790us/step - loss: 0.7795 - acc: 0.7339 - val_loss: 0.7362 - val_acc: 0.7519
# Epoch 18/30
# 50000/50000 [==============================] - 39s 788us/step - loss: 0.7728 - acc: 0.7374 - val_loss: 0.7334 - val_acc: 0.7556
# Epoch 19/30
# 50000/50000 [==============================] - 39s 776us/step - loss: 0.7682 - acc: 0.7400 - val_loss: 0.7554 - val_acc: 0.7509
# Epoch 20/30
# 50000/50000 [==============================] - 40s 791us/step - loss: 0.7706 - acc: 0.7412 - val_loss: 0.7835 - val_acc: 0.7450
# Epoch 21/30
# 50000/50000 [==============================] - 39s 770us/step - loss: 0.7682 - acc: 0.7410 - val_loss: 0.7770 - val_acc: 0.7489
# Epoch 22/30
# 50000/50000 [==============================] - 37s 746us/step - loss: 0.7701 - acc: 0.7426 - val_loss: 0.7285 - val_acc: 0.7509
# Epoch 23/30
# 50000/50000 [==============================] - 37s 741us/step - loss: 0.7671 - acc: 0.7425 - val_loss: 0.7652 - val_acc: 0.7504
# Epoch 24/30
# 50000/50000 [==============================] - 42s 830us/step - loss: 0.7681 - acc: 0.7415 - val_loss: 0.7768 - val_acc: 0.7412
# Epoch 25/30
# 50000/50000 [==============================] - 40s 804us/step - loss: 0.7657 - acc: 0.7448 - val_loss: 0.7982 - val_acc: 0.7565
# Epoch 26/30
# 50000/50000 [==============================] - 41s 812us/step - loss: 0.7649 - acc: 0.7445 - val_loss: 0.7341 - val_acc: 0.7558
# Epoch 27/30
# 50000/50000 [==============================] - 40s 805us/step - loss: 0.7676 - acc: 0.7450 - val_loss: 0.7070 - val_acc: 0.7636
# Epoch 28/30
# 50000/50000 [==============================] - 40s 797us/step - loss: 0.7658 - acc: 0.7430 - val_loss: 0.7606 - val_acc: 0.7496
# Epoch 29/30
# 50000/50000 [==============================] - 40s 810us/step - loss: 0.7651 - acc: 0.7461 - val_loss: 0.7033 - val_acc: 0.7662
# Epoch 30/30
# 50000/50000 [==============================] - 44s 871us/step - loss: 0.7676 - acc: 0.7465 - val_loss: 0.7403 - val_acc: 0.7577
# Saved trained model at /content/saved_models/keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 2s 173us/step
# Test loss: 0.7402799317359924
# Test accuracy: 0.7577
